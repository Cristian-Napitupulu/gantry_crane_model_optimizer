# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numba import jit, float64
import time
import os
import copy

# %%
def load_excel_data(directory):
    """
    Load all Excel files and their sheets from the specified directory into a list of dataframes.

    Parameters:
    directory (str): The path to the folder containing the Excel files.

    Returns:
    list: A list of pandas dataframes containing the data from each sheet in the Excel files.
    """
    # Initialize an empty list to store dataframes
    datasets = []
    # Iterate over each file in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".xlsx"):
            file_path = os.path.join(directory, filename)

            # Load the Excel file
            excel_file = pd.ExcelFile(file_path)

            # Iterate over each sheet in the Excel file
            for sheet_name in excel_file.sheet_names:
                # Load the sheet into a dataframe and append to the datasets list
                df = pd.read_excel(excel_file, sheet_name=sheet_name)
                datasets.append(df)

    return datasets


def save_datasets_to_excel(datasets, output_file):
    """
    Save a list of dataframes to a single Excel file with each dataframe in a separate sheet.

    Parameters:
    datasets (list): A list of tuples containing filename, sheet name, and dataframe.
    output_file (str): The path to the output Excel file.
    """
    with pd.ExcelWriter(output_file, engine="openpyxl") as writer:
        for i, (df) in enumerate(datasets):
            sheet_name_clean = f"Sheet_{i}"[
                :31
            ]  # Excel sheet names must be <= 31 chars
            df.to_excel(writer, sheet_name=sheet_name_clean, index=False)

# %%
# Example usage of the function
directory = "data/"
datasets = load_excel_data(directory)

# %%
# for i in range(len(datasets)):
#     plt.plot(datasets[i]['timestamp'], datasets[i]['trolley_position'], label='Trolley Position')
#     plt.plot(datasets[i]['timestamp'], datasets[i]['cable_length'], label='Cable Length')
#     plt.xlabel('Time')
#     plt.title(f"Data Set {i+1}")
#     plt.legend()
#     plt.show()

# %%
DURATION = 15  # duration in seconds
DT = 0.0001  # time increment in seconds
# Create a time array
time_array = np.arange(0, DURATION + DT, DT)
NUM_STEPS = len(time_array)

interpolated_datasets = []
for i in range(len(datasets)):
    new_trolley_position = np.interp(
        time_array, datasets[i]["timestamp"], datasets[i]["trolley_position"]
    )
    new_cable_length = np.interp(
        time_array, datasets[i]["timestamp"], datasets[i]["cable_length"]
    )
    new_sway_angle = np.interp(
        time_array, datasets[i]["timestamp"], datasets[i]["sway_angle"]
    )
    new_trolley_motor_voltage = np.interp(
        time_array, datasets[i]["timestamp"], datasets[i]["trolley_motor_voltage"]
    )
    new_hoist_motor_voltage = np.interp(
        time_array, datasets[i]["timestamp"], datasets[i]["hoist_motor_voltage"]
    )

    interpolated_df = {
        "time": time_array,
        "trolley_position": new_trolley_position,
        "cable_length": new_cable_length,
        "sway_angle": new_sway_angle,
        "trolley_motor_voltage": new_trolley_motor_voltage,
        "hoist_motor_voltage": new_hoist_motor_voltage,
    }

    interpolated_datasets.append(interpolated_df)

# %%
# for i in range(len(interpolated_datasets)):
    # plt.plot(interpolated_datasets[i]['time'], interpolated_datasets[i]['trolley_position'], label='Trolley Position')
    # plt.plot(interpolated_datasets[i]['time'], interpolated_datasets[i]['cable_length'], label='Cable Length')
    # plt.xlabel('Time')
    # plt.title(f"Interpolated Data Set {i+1}")
    # plt.legend()
    # plt.show()

# %%
# Open the JSON file
with open("gantry_crane_parameters.json", "r") as file:
    data = json.load(file)

global all_parameters; all_parameters = data["gantry_crane_system_model"]["parameters"]
measured_parameters = {}
approximated_parameters = {}

for parameter in all_parameters:
    value = all_parameters[parameter]["value"]
    unit = all_parameters[parameter]["unit"]
    description = all_parameters[parameter]["description"]

    # print(f"{parameter}: {value} {unit} ({description})")

    if all_parameters[parameter]["measured"]:
        measured_parameters[parameter] = all_parameters[parameter]
    else:
        approximated_parameters[parameter] = all_parameters[parameter]

print(f'Number of approximated parameters: {len(approximated_parameters)}')
# Out:
# Number of approximated parameters: 13

# %%
from model import Simulator
import utility as util

simulator = Simulator(DT, NUM_STEPS)

# %%
def cost_function(params, data_arrs):
    """
    Cost function is the sum of the root mean squared errors between the interpolated data and the simulated data.
    """
    # Extract the parameters
    input_voltages = {
        "trolley_motor_voltage": data_arrs["trolley_motor_voltage"],
        "hoist_motor_voltage": data_arrs["hoist_motor_voltage"],
    }
    var_init_conditions = {
        "x": data_arrs["trolley_position"][0],
        "l": data_arrs["cable_length"][0],
        "theta": data_arrs["sway_angle"][0],
    }
    # print(f"Simulating with parameters: {params}")
    # print(f"Inital conditions: {var_init_conditions}")
    
    simulator.simulate(params, input_voltages, var_init_conditions)
    simulation_results = simulator.get_results()
    sum_RMSE = util.calculate_sum_root_mean_squared_errors(
        pd.DataFrame(simulation_results), pd.DataFrame(data_arrs)
    )
    if np.isnan(sum_RMSE):
        print(f"Sum RMSE is NaN")
        return np.inf
    
    print(f"\rSum RMSE: \t{round(sum_RMSE, 5)}", end="\r")

    return sum_RMSE

# %%
optimize_range = {
    "trolley_mass": (1.0, 5.0),  # Done
    "trolley_damping_coefficient": (0.1, 10.0),  # Done
    "cable_damping_coefficient": (0.1, 10.0),  # Done
    "trolley_motor_rotator_inertia": (0.00001, 0.001),  # Done
    "trolley_motor_damping_coefficient": (0.1, 10.0),
    "trolley_motor_back_emf_constant": (0.001, 0.1),  # Done
    "trolley_motor_torque_constant": (0.01, 1.0),  # Done
    "hoist_motor_rotator_inertia": (0.000001, 0.0001),  # Done
    "hoist_motor_damping_coefficient": (0.1, 10.0),
    "hoist_motor_back_emf_constant": (0.01, 1.0),  # Done
    "hoist_motor_torque_constant": (0.0001, 0.01),  # Done
    "trolley_motor_activation_threshold_voltage": (0.1, 10.0),  # Done
    "hoist_motor_activation_threshold_voltage": (0.1, 10.0),  # Done
}

# %% [markdown]
# ### Gradient Descent

# %%
LEARNING_RATE = 0.01
MAX_VARIATIONS = 2
MAX_ITERATIONS = 1000
NUM_DATASETS = len(interpolated_datasets)
NUM_DATASETS = 3

# %%
best_parameters = copy.deepcopy(all_parameters)
best_average_total_cost = 0
for i in range(NUM_DATASETS):
    best_average_total_cost += cost_function(best_parameters, interpolated_datasets[i])
    print(f"Best Cost: {best_average_total_cost}", end="\r")
# Out:
# Best Cost: 61.90001337568192

# %%
variation = 0
while variation <= MAX_VARIATIONS:
    current_parameters = copy.deepcopy(all_parameters)
    for parameter in approximated_parameters:
        current_parameters[parameter]["value"] = np.random.uniform(
            optimize_range[parameter][0], optimize_range[parameter][1]
        )

    print(f"Variation: {variation}")
    for parameter in approximated_parameters:
        print(f"{parameter}: {current_parameters[parameter]['value']}", end=" | ")
    print()

    diverge = False
    for iteration in range(MAX_ITERATIONS):     
        print(f"Iteration: {iteration}")

        # Loop through each parameter to optimize
        for parameter in approximated_parameters:
            if diverge:
                break

            # Loop through each dataset to calculate the cost and gradient
            total_parameter_gradient = 0
            for dataset_num in range(NUM_DATASETS):
                if diverge:
                    break

                print(f"Optimizing {parameter} for dataset {dataset_num}", end="\r")

                # Calculate the cost function
                cost = cost_function(current_parameters, interpolated_datasets[dataset_num])

                if cost == np.inf:
                    print(f"Cost is infinite")
                    diverge = True
                    break

                # Calculate the gradient
                new_parameters = copy.deepcopy(current_parameters)
                new_parameters[parameter]["value"] += 0.000001
                new_cost = cost_function(new_parameters, interpolated_datasets[dataset_num])
                gradient = (new_cost - cost) / 0.000001
                total_parameter_gradient += gradient
            
            # Update the parameter
            current_parameters[parameter]["value"] -= LEARNING_RATE * total_parameter_gradient

            if current_parameters[parameter]["value"] < 0:
                current_parameters[parameter]["value"] = optimize_range[parameter][0]

            print(f"{parameter} || Cost: {cost}, Gradient: {total_parameter_gradient}, New Value: {current_parameters[parameter]['value']}")
            print("-" * 100)
        
        if diverge:
            break
       
        else:
            average_total_cost = 0
            for dataset_num in range(NUM_DATASETS):    
                average_total_cost += cost_function(current_parameters, interpolated_datasets[dataset_num])
            average_total_cost /= NUM_DATASETS
            
            if average_total_cost < best_average_total_cost:
                best_average_total_cost = average_total_cost
                best_parameters = copy.deepcopy(current_parameters)
                print(f"New Best Cost: {best_average_total_cost}")
                print(best_parameters)

                # Save the best parameters to a JSON file
                with open("GD_best_gantry_crane_parameters.json", "w") as file:
                    json.dump(best_parameters, file, indent=4)

    if diverge:
        variation -= 1
        if variation < 0:
            variation = 0
        print("Variation Failed. Restarting current variation...")
        print("*" * 100)
        continue

    print(f"Results: Average Cost: {average_total_cost}, Best Average Cost: {best_average_total_cost}")
    print(f"Best Parameters:", end=" ")
    for parameter in approximated_parameters:
        print(f"{parameter}: {best_parameters[parameter]['value']}", end=" | ")
    print()
    print("*" * 100)

    variation += 1
# Out:
# Variation: 0
# trolley_mass: 4.050215211908318 | trolley_damping_coefficient: 1.6895608831815085 | cable_damping_coefficient: 3.090401138818727 | hoist_motor_activation_threshold_voltage: 2.099740231925906 | hoist_motor_rotator_inertia: 5.780886972797849e-05 | hoist_motor_damping_coefficient: 1.2098164617234533 | hoist_motor_torque_constant: 0.007579946364295252 | hoist_motor_back_emf_constant: 0.49841704627158573 | trolley_motor_activation_threshold_voltage: 7.391908397419534 | trolley_motor_rotator_inertia: 8.33093015664635e-05 | trolley_motor_damping_coefficient: 8.76919844583819 | trolley_motor_torque_constant: 0.902455521836503 | trolley_motor_back_emf_constant: 0.005519118565804166 |
# Iteration: 0
# trolley_mass || Cost: 0.14000700341202818, Gradient: -3.3681391009565687e-08, New Value: 4.050215212245132
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.14000700341202818, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.14000700341202818, Gradient: 9.488729246776018e-06, New Value: 3.0904010439314344
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.14000700341171146, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.14000700341171146, Gradient: 0.004333119113519857, New Value: 1.4477678592779927e-05
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.14000694339284778, Gradient: 0.042220202445264476, New Value: 1.2093942596990006
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.14000072981294073, Gradient: -0.04548511825519519, New Value: 0.008034797546847203
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.13999308940949642, Gradient: 3.5726935299074114e-05, New Value: 0.49841668900223274
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.1399930894050469, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.1399930894050469, Gradient: -0.00014551650162619723, New Value: 8.476446658272548e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.13999308926089105, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.13999308926089105, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.13999308926089105, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.1318390322329859
# {'trolley_mass': {'value': 4.050215212245132, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.0904010439314344, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1.4477678592779927e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.2093942596990006, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.008034797546847203, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.49841668900223274, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 8.476446658272548e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 1
# trolley_mass || Cost: 0.13999308926089105, Gradient: -3.5485503424581566e-08, New Value: 4.050215212599987
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.13999308926089105, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.13999308926089105, Gradient: 9.506478937382212e-06, New Value: 3.090400948866645
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.13999308926057313, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.13999308926057313, Gradient: 0.004337084719141515, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.1399930705747677, Gradient: 0.04226573492582819, New Value: 1.2089716023497423
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.13998684340883774, Gradient: -0.04549819948573841, New Value: 0.008489779541704587
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.13997919856972385, Gradient: 3.7790617857247355e-05, New Value: 0.49841631109605417
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.13997919856474478, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.13997919856474478, Gradient: -0.00014513526491732875, New Value: 8.621581923189876e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.13997919842133935, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.13997919842133935, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.13997919842133935, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.13182615581887336
# {'trolley_mass': {'value': 4.050215212599987, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.090400948866645, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1e-06, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.2089716023497423, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.008489779541704587, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.49841631109605417, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 8.621581923189876e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 2
# trolley_mass || Cost: 0.13997919842133935, Gradient: -3.176625629208729e-08, New Value: 4.050215212917649
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.1399791984213393, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.1399791984213393, Gradient: 9.521744503970808e-06, New Value: 3.0904008536492
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.13997919842102557, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.13997919842102557, Gradient: 0.004341034934296495, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.13997919842102557, Gradient: 0.04231124844933376, New Value: 1.208548489865249
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.13997295765686113, Gradient: -0.04551130718122298, New Value: 0.008944892613516817
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.1399653083770615, Gradient: 3.9864334056005646e-05, New Value: 0.4984159124527136
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.13996530837152144, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.13996530837152144, Gradient: -0.00014474191289970406, New Value: 8.76632383608958e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.13996530822888248, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.13996530822888248, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.13996530822888248, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.13181328207375126
# {'trolley_mass': {'value': 4.050215212917649, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.0904008536492, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1e-06, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.208548489865249, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.008944892613516817, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.4984159124527136, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 8.76632383608958e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 3
# trolley_mass || Cost: 0.13996530822888248, Gradient: -3.176625629208729e-08, New Value: 4.050215213235312
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.13996530822888248, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.13996530822888248, Gradient: 9.517261978508884e-06, New Value: 3.09040075847658
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.13996530822856615, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.13996530822856615, Gradient: 0.0043450161385516495, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.13996530822856615, Gradient: 0.04235687710296698, New Value: 1.2081249210942193
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.13995905382116938, Gradient: -0.04552441032479315, New Value: 0.009400136716764748
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.13995140009615284, Gradient: 4.194489200415319e-05, New Value: 0.49841549300379356
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.13995140009002607, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.13995140009002607, Gradient: -0.00014436107864668202, New Value: 8.910684914736262e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.1399513999481266, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.1399513999481266, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.1399513999481266, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.13180039146663772
# {'trolley_mass': {'value': 4.050215213235312, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.09040075847658, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1e-06, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.2081249210942193, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.009400136716764748, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.49841549300379356, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 8.910684914736262e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 4
# trolley_mass || Cost: 0.1399513999481266, Gradient: -3.008704396734174e-08, New Value: 4.050215213536182
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.1399513999481266, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.1399513999481266, Gradient: 9.554995683558332e-06, New Value: 3.090400662926623
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.139951399947808, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.139951399947808, Gradient: 0.004348999174674795, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.139951399947808, Gradient: 0.042402590855195044, New Value: 1.2077008951856674
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.1399451318564636, Gradient: -0.045537572962439654, New Value: 0.009855512446389145
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.13993747367093023, Gradient: 4.404786257961035e-05, New Value: 0.49841505252516777
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.1399374736641697, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.1399374736641697, Gradient: -0.00014398941761140094, New Value: 9.054674332347663e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.1399374735230109, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.1399374735230109, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.1399374735230109, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.13178748394549442
# {'trolley_mass': {'value': 4.050215213536182, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.090400662926623, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1e-06, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.2077008951856674, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.009855512446389145, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.49841505252516777, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 9.054674332347663e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 5
# trolley_mass || Cost: 0.1399374735230109, Gradient: -3.154421168716226e-08, New Value: 4.050215213851624
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.1399374735230109, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.1399374735230109, Gradient: 9.556855307124579e-06, New Value: 3.09040056735807
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.1399374735226939, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.1399374735226939, Gradient: 0.004352977561739024, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.1399374735226939, Gradient: 0.04244835839772865, New Value: 1.20727641160169
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.13993119171118065, Gradient: -0.04555072406764449, New Value: 0.01031101968706559
# ----------------------------------------------------------------------------------------------------
# hoist_motor_back_emf_constant || Cost: 0.13992352906176886, Gradient: 4.6123924124508164e-05, New Value: 0.4984145912859265
# ----------------------------------------------------------------------------------------------------
# trolley_motor_activation_threshold_voltage || Cost: 0.13992352905435199, Gradient: 0.0, New Value: 7.391908397419534
# ----------------------------------------------------------------------------------------------------
# trolley_motor_rotator_inertia || Cost: 0.13992352905435199, Gradient: -0.00014361577205246334, New Value: 9.198290104400127e-05
# ----------------------------------------------------------------------------------------------------
# trolley_motor_damping_coefficient || Cost: 0.13992352891392637, Gradient: 0.0, New Value: 8.76919844583819
# ----------------------------------------------------------------------------------------------------
# trolley_motor_torque_constant || Cost: 0.13992352891392637, Gradient: 0.0, New Value: 0.902455521836503
# ----------------------------------------------------------------------------------------------------
# trolley_motor_back_emf_constant || Cost: 0.13992352891392637, Gradient: 0.0, New Value: 0.005519118565804166
# ----------------------------------------------------------------------------------------------------
# New Best Cost: 0.131774559473372
# {'trolley_mass': {'value': 4.050215213851624, 'unit': 'kg', 'description': 'Mass of the trolley', 'measured': False}, 'container_mass': {'value': 1.128, 'unit': 'kg', 'description': 'Mass of the container', 'measured': True}, 'trolley_damping_coefficient': {'value': 1.6895608831815085, 'unit': 'Ns/m', 'description': 'Damping coefficient of the trolley', 'measured': False}, 'cable_damping_coefficient': {'value': 3.09040056735807, 'unit': 'Ns/m', 'description': 'Damping coefficient of the cable', 'measured': False}, 'gravity_acceleration': {'value': 9.81, 'unit': 'm/s^2', 'description': 'Acceleration due to gravity', 'measured': True}, 'hoist_motor_activation_threshold_voltage': {'value': 2.099740231925906, 'unit': 'V', 'description': 'Activation threshold voltage of the hoist motor', 'measured': False}, 'hoist_motor_inductance': {'value': 0.0073, 'unit': 'H', 'description': 'Inductance of the hoist motor', 'measured': True}, 'hoist_motor_resistance': {'value': 9.5, 'unit': 'ohm', 'description': 'Resistance of the hoist motor', 'measured': True}, 'hoist_motor_rotator_inertia': {'value': 1e-06, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the hoist motor rotor', 'measured': False}, 'hoist_motor_damping_coefficient': {'value': 1.20727641160169, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the hoist motor', 'measured': False}, 'hoist_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the hoist motor', 'measured': True}, 'hoist_motor_torque_constant': {'value': 0.01031101968706559, 'unit': 'Nm/A', 'description': 'Torque constant of the hoist motor', 'measured': False}, 'hoist_motor_back_emf_constant': {'value': 0.4984145912859265, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the hoist motor', 'measured': False}, 'trolley_motor_activation_threshold_voltage': {'value': 7.391908397419534, 'unit': 'V', 'description': 'Activation threshold voltage of the trolley motor', 'measured': False}, 'trolley_motor_inductance': {'value': 0.0001048, 'unit': 'H', 'description': 'Inductance of the trolley motor', 'measured': True}, 'trolley_motor_resistance': {'value': 0.39, 'unit': 'ohm', 'description': 'Resistance of the trolley motor', 'measured': True}, 'trolley_motor_rotator_inertia': {'value': 9.198290104400127e-05, 'unit': 'kg.m^2', 'description': 'Rotational inertia of the trolley motor rotor', 'measured': False}, 'trolley_motor_damping_coefficient': {'value': 8.76919844583819, 'unit': 'Ns.m/rad', 'description': 'Damping coefficient of the trolley motor', 'measured': False}, 'trolley_motor_pulley_radius': {'value': 0.015, 'unit': 'm', 'description': 'Radius of the pulley connected to the trolley motor', 'measured': True}, 'trolley_motor_torque_constant': {'value': 0.902455521836503, 'unit': 'Nm/A', 'description': 'Torque constant of the trolley motor', 'measured': False}, 'trolley_motor_back_emf_constant': {'value': 0.005519118565804166, 'unit': 'V/(rad/s)', 'description': 'Back EMF constant of the trolley motor', 'measured': False}}
# Iteration: 6
# trolley_mass || Cost: 0.13992352891392637, Gradient: -3.287647931671245e-08, New Value: 4.050215214180389
# ----------------------------------------------------------------------------------------------------
# trolley_damping_coefficient || Cost: 0.13992352891392637, Gradient: 0.0, New Value: 1.6895608831815085
# ----------------------------------------------------------------------------------------------------
# cable_damping_coefficient || Cost: 0.13992352891392637, Gradient: 9.554995683558332e-06, New Value: 3.0904004718081133
# ----------------------------------------------------------------------------------------------------
# hoist_motor_activation_threshold_voltage || Cost: 0.13992352891360058, Gradient: 0.0, New Value: 2.099740231925906
# ----------------------------------------------------------------------------------------------------
# hoist_motor_rotator_inertia || Cost: 0.13992352891360058, Gradient: 0.004356974059316343, New Value: 1e-06
# ----------------------------------------------------------------------------------------------------
# hoist_motor_damping_coefficient || Cost: 0.13992352891360058, Gradient: 0.0424942531440653, New Value: 1.2068514690702494
# ----------------------------------------------------------------------------------------------------
# hoist_motor_torque_constant || Cost: 0.13991723333473227, Gradient: -0.04556392046994873, New Value: 0.010766658891765077
# ----------------------------------------------------------------------------------------------------
# Optimizing hoist_motor_back_emf_constant for dataset 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 32
#      29 print(f"Optimizing {parameter} for dataset {dataset_num}", end="\r")
#      31 # Calculate the cost function
# ---> 32 cost = cost_function(current_parameters, interpolated_datasets[dataset_num])
#      34 if cost == np.inf:
#      35     print(f"Cost is infinite")
#
# Cell In[9], line 20, in cost_function(params, data_arrs)
#      18 simulator.simulate(params, input_voltages, var_init_conditions)
#      19 simulation_results = simulator.get_results()
# ---> 20 sum_RMSE = util.calculate_sum_root_mean_squared_errors(
#      21     pd.DataFrame(simulation_results), pd.DataFrame(data_arrs)
#      22 )
#      23 if np.isnan(sum_RMSE):
#      24     print(f"Sum RMSE is NaN")
#
# File d:\0 - Tugas Akhir\Code\utility.py:23, in calculate_sum_root_mean_squared_errors(interpolated_array_, simulated_array_)
#      21 sum_squared_error = 0.0
#      22 for j in range(n):
# ---> 23     sum_squared_error += (y1[j] - y2[j]) ** 2
#      24 root_mean_squared_errors = np.sqrt(sum_squared_error / n)
#      25 sum_root_mean_squared_errors += root_mean_squared_errors
#
# File d:\0 - Tugas Akhir\Code\.venv\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File d:\0 - Tugas Akhir\Code\.venv\Lib\site-packages\pandas\core\series.py:1220, in Series._get_value(self, label, takeable)
#    1217     new_mgr = self._mgr.get_rows_with_mask(indexer)
#    1218     return self._constructor_from_mgr(new_mgr, axes=new_mgr.axes).__finalize__(self)
# -> 1220 def _get_value(self, label, takeable: bool = False):
#    1221     """
#    1222     Quickly retrieve single value at passed index label.
#    1223
#    (...)
#    1231     scalar value
#    1232     """
#    1233     if takeable:
#
# KeyboardInterrupt:
